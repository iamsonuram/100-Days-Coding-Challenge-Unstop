# %% [markdown]
# ## Problem Statement
# You wish to help Ashish, who possesses a collection of N strings, some of which may be duplicated, and has been assigned the task of finding the kth unique string.
#
# If the number of unique strings is less than k, he needs to display -1. Considering you are Ashish's best friend can you assist him with this challenge?
#
# ## Input Format
# - The first line contains an integer N denoting the number of strings.
# - The next N lines contain strings.
# - The next line contains an integer k.
#
# ## Output Format
# The output contains the kth distinct string. If there are less than k unique string display -1.
#
# ## Constraints
# - 1 <= N <= 10^3
# - 1 <= String.length() <= 10^3
#
# ![image.png](attachment:cd7ea66b-062d-4fac-afbb-4e954d4e3fbf.png)
# ![image.png](attachment:035fd161-73f1-4e22-b60a-b76daf6449c2.png)

# %%
ui = []
n = int(input())
for i in range(n):
    ch = input()
    ui.append(ch)
k = int(input("Enter the value of k:"))
print(ui)
# Out:
#  2
#  a
#  a
# Enter the value of k: 1
# ['a', 'a']

# %%
2
a
a
1

# %%
unique_char_count = {}
unique_char = []
count = 1
for i in ui:
    if i not in unique_char_count:
        unique_char_count[i] = count
    elif i in unique_char_count:
        unique_char_count[i] += 1

# %%
unique_char_count
# Out:
# {'a': 2}

# %%
for a in unique_char_count:
    if unique_char_count[a] == 1:
        unique_char.append(a)

# %%
len(unique_char)
# Out:
# 0

# %%
if len(unique_char) < k:
        print(-1)
    
for index in range(1,len(unique_char)+1):
    if index == k:
        print(unique_char[index-1])
# Out:
# -1
